# %% [markdown]
# <a href="https://colab.research.google.com/github/FranklineMisango/Deep_Learning_Projects/blob/main/Xpay_DeepLearner_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #This project encompasses the Xpay's official AI that assists the team in Research in payment patterns in Fintech
# #As a starting step, It currently automates the Team's research on Stock and Crypto in China's GBA

# %%
#Baseline_Setup_and_dependencies
#Pegasus Tokenizer, NLP for summarization
#BS4 scraps the web for news
import requests
from transformers import PegasusTokenizer, PegasusForConditionalGeneration, TFPegasusForConditionalGeneration
from bs4 import BeautifulSoup

# %%
#Loading and saving the summarization models  from the Hugging face model
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
tokenizer = AutoTokenizer.from_pretrained("human-centered-summarization/financial-summarization-pegasus")
model = AutoModelForSeq2SeqLM.from_pretrained("human-centered-summarization/financial-summarization-pegasus")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]

# %%
#Test article summarization for tesla Undercovering in china 
#Used from yFinance
url = "https://au.finance.yahoo.com/news/china-restricting-tesla-use-uncovers-a-significant-challenge-for-elon-musk-expert-161921664.html"
r = requests.get(url)
soup = BeautifulSoup(r.text , 'html.parser')
paragraphs = soup.find_all('p')

# %%
#TODO-Fix the Issues on r responses and paragraph responses
r
# Out:
# <Response [404]>

# %%
#Building a News and Sentiment Pipleline
